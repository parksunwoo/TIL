# %%
import numpy as np
import pandas as pd

# %%
print(np.array.__doc__)
# Out:
# array(object, dtype=None, copy=True, order='K', subok=False, ndmin=0)
#
#     Create an array.
#
#     Parameters
#     ----------
#     object : array_like
#         An array, any object exposing the array interface, an object whose
#         __array__ method returns an array, or any (nested) sequence.
#     dtype : data-type, optional
#         The desired data-type for the array.  If not given, then the type will
#         be determined as the minimum type required to hold the objects in the
#         sequence.  This argument can only be used to 'upcast' the array.  For
#         downcasting, use the .astype(t) method.
#     copy : bool, optional
#         If true (default), then the object is copied.  Otherwise, a copy will
#         only be made if __array__ returns a copy, if obj is a nested sequence,
#         or if a copy is needed to satisfy any of the other requirements
#         (`dtype`, `order`, etc.).
#     order : {'K', 'A', 'C', 'F'}, optional
# ...

# %%
ser = pd.Series([1,3,5,5,8])
ser
# Out:
# 0    1
# 1    3
# 2    5
# 3    5
# 4    8
# dtype: int64

# %%
np.where(ser >= 5, "PASS", "Fail")
# Out:
# array(['Fail', 'Fail', 'PASS', 'PASS', 'PASS'], dtype='<U4')

# %%
(ser >= 5) + 0
(ser >= 5) * 1
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# dtype: int32

# %%
df = pd.read_csv("iris_missing.csv")
df_sub = df.head()
df_sub
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal.Length    143 non-null float64
# Sepal.Width     137 non-null float64
# Petal.Length    136 non-null float64
# Petal.Width     144 non-null float64
# Species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df["Sepal.Length"].mean()
# Out:
# 5.853846153846154

# %%
np.nanmean(df["Sepal.Length"])
# Out:
# 5.8538461538461535

# %%
round(df["Sepal.Length"].mean(),2)
# Out:
# 5.85

# %%
df_sub.fillna(999)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1        999.0         999.0          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_sub["Sepal.Width"].fillna(999)
# Out:
# 0    999.0
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# Name: Sepal.Width, dtype: float64

# %%
df_sub.fillna(value={"Sepal.Width":80, "Petal.Length" : -77})
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1         80.0         -77.0          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_sub["test"] = df_sub["Sepal.Width"].fillna(df_sub["Sepal.Width"].mean())
df_sub
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species   test
# 0           5.1          NaN           NaN          0.2  setosa  3.225
# 1           4.9          3.0           1.4          0.2  setosa  3.000
# 2           4.7          3.2           1.3          0.2  setosa  3.200
# 3           4.6          3.1           1.5          0.2  setosa  3.100
# 4           5.0          3.6           1.4          0.2  setosa  3.600

# %%
df_sub.loc[:, "test"] = df_sub["Sepal.Width"].fillna(df_sub["Sepal.Width"].mean())
df_sub
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species   test
# 0           5.1          NaN           NaN          0.2  setosa  3.225
# 1           4.9          3.0           1.4          0.2  setosa  3.000
# 2           4.7          3.2           1.3          0.2  setosa  3.200
# 3           4.6          3.1           1.5          0.2  setosa  3.100
# 4           5.0          3.6           1.4          0.2  setosa  3.600

# %%
df_sub["Petal.Length"] = df_sub["Petal.Length"].replace(1.4, np.nan)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_sub
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species   test
# 0           5.1          NaN           NaN          0.2  setosa  3.225
# 1           4.9          3.0           NaN          0.2  setosa  3.000
# 2           4.7          3.2           1.3          0.2  setosa  3.200
# 3           4.6          3.1           1.5          0.2  setosa  3.100
# 4           5.0          3.6           NaN          0.2  setosa  3.600

# %%
df_sub.loc[:, "Petal.Length"] = df_sub["Petal.Length"].replace(1.4, np.nan)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_sub
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species   test
# 0           5.1          NaN           NaN          0.2  setosa  3.225
# 1           4.9          3.0           NaN          0.2  setosa  3.000
# 2           4.7          3.2           1.3          0.2  setosa  3.200
# 3           4.6          3.1           1.5          0.2  setosa  3.100
# 4           5.0          3.6           NaN          0.2  setosa  3.600

# %%
df_mis = df.iloc[5:9, 0:-1]
df_mis
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 5           5.4          3.9           1.7          0.4
# 6           NaN          NaN           NaN          NaN
# 7           5.0          3.4           NaN          0.2
# 8           4.4          2.9           1.4          0.2

# %%
df_mis.dropna()
df_mis.dropna(how= "any")
df_mis.dropna(how= "all")
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 5           5.4          3.9           1.7          0.4
# 7           5.0          3.4           NaN          0.2
# 8           4.4          2.9           1.4          0.2

# %%
df_mis[df_mis["Sepal.Width"].isnull()]
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 6           NaN          NaN           NaN          NaN

# %%
df_mis[df_mis["Sepal.Width"].notnull()]
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 5           5.4          3.9           1.7          0.4
# 7           5.0          3.4           NaN          0.2
# 8           4.4          2.9           1.4          0.2

# %%
df_mis[(df_mis["Sepal.Width"].notnull()) & (df_mis["Sepal.Length"] >= 5)]
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 5           5.4          3.9           1.7          0.4
# 7           5.0          3.4           NaN          0.2

# %%
df_notnull = df_mis[df_mis["Petal.Length"].notnull()]

# %%
df_notnull
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 5           5.4          3.9           1.7          0.4
# 8           4.4          2.9           1.4          0.2

# %%
df = pd.read_csv("bike.csv")

# %%
df_sub = df.loc[df["casual"] >= df["casual"].quantile(0.99), :] # 최대값에 가깝다 상위 1프로 경계

# %%
df_sub.head(10)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 2751  2011-07-03 13:00:00       3        0           0        1  32.80
# 2775  2011-07-04 13:00:00       3        1           0        2  31.98
# 3687  2011-09-04 13:00:00       3        0           0        2  31.98
# 4236  2011-10-08 13:00:00       4        0           0        1  25.42
# 4237  2011-10-08 14:00:00       4        0           0        1  25.42
# 4238  2011-10-08 15:00:00       4        0           0        1  27.06
# 4261  2011-10-09 14:00:00       4        0           0        1  27.88
# 4405  2011-10-15 14:00:00       4        0           0        1  24.60
# 6725  2012-03-17 12:00:00       1        0           0        1  22.96
# 6726  2012-03-17 13:00:00       1        0           0        1  24.60
#
#        atemp  humidity  windspeed  casual  registered  count
# 2751  38.635        59    15.0013     248         173    421
# 2775  35.605        49     0.0000     242         181    423
# ...

# %%
df_sub["casual"].quantile([0, 1])
# Out:
# 0.0    241.0
# 1.0    367.0
# Name: casual, dtype: float64

# %%
len(df_sub)
# Out:
# 109

# %%
"aa" + "bb"
# Out:
# 'aabb'

# %%
"aa" * 3
# Out:
# 'aaaaaa'

# %%
month = 2
str(month) + "월"
# Out:
# '2월'

# %%
text = "aaBcde"
text.capitalize()
# Out:
# 'Aabcde'

# %%
text.upper()
# Out:
# 'AABCDE'

# %%
text.lower()
# Out:
# 'aabcde'

# %%
runfile("./hello.py")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-0025da875a9f> in <module>
# ----> 1 runfile("./hello.py")
#
# NameError: name 'runfile' is not defined

# %%
def udf_01(a):
    print(a)

# %%
udf_01("Hello?")
# Out:
# Hello?

# %%
df = pd.read_csv("bike.csv")
df_sub = df.iloc[:6, 9:12]
df_sub
# Out:
#    casual  registered  count
# 0       3          13     16
# 1       8          32     40
# 2       5          27     32
# 3       3          10     13
# 4       0           1      1
# 5       0           1      1

# %%
df_sub.sort_values(["casual"], ascending=[False])
# Out:
#    casual  registered  count
# 1       8          32     40
# 2       5          27     32
# 0       3          13     16
# 3       3          10     13
# 4       0           1      1
# 5       0           1      1

# %%
df_sub.sort_values(["casual"], ascending=False)
# Out:
#    casual  registered  count
# 1       8          32     40
# 2       5          27     32
# 0       3          13     16
# 3       3          10     13
# 4       0           1      1
# 5       0           1      1

# %%
df_sub.sort_values(["casual"], ascending=[True])
# Out:
#    casual  registered  count
# 4       0           1      1
# 5       0           1      1
# 0       3          13     16
# 3       3          10     13
# 2       5          27     32
# 1       8          32     40

# %%
df_sub.sort_values(["casual"], ascending=True)
# Out:
#    casual  registered  count
# 4       0           1      1
# 5       0           1      1
# 0       3          13     16
# 3       3          10     13
# 2       5          27     32
# 1       8          32     40

# %%
df_sub.sort_values(["casual"])
# Out:
#    casual  registered  count
# 4       0           1      1
# 5       0           1      1
# 0       3          13     16
# 3       3          10     13
# 2       5          27     32
# 1       8          32     40

# %%
df_sub.sort_values(["casual", "registered"], ascending=[False, False])
# Out:
#    casual  registered  count
# 1       8          32     40
# 2       5          27     32
# 0       3          13     16
# 3       3          10     13
# 4       0           1      1
# 5       0           1      1

# %%
df_sub = df_sub.reset_index(drop=True)
df_sub
# Out:
#    level_0  index  casual  registered  count
# 0        0      0       3          13     16
# 1        1      1       8          32     40
# 2        2      2       5          27     32
# 3        3      3       3          10     13
# 4        4      4       0           1      1
# 5        5      5       0           1      1

# %%
df = pd.read_csv("diamonds.csv")
df_sub = df.loc[:, "price":]
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9       0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# ...

# %%
df_sub
# Out:
#        price     x     y     z
# 0        326  3.95  3.98  2.43
# 1        326  3.89  3.84  2.31
# 2        327  4.05  4.07  2.31
# 3        334  4.20  4.23  2.63
# 4        335  4.34  4.35  2.75
# 5        336  3.94  3.96  2.48
# 6        336  3.95  3.98  2.47
# 7        337  4.07  4.11  2.53
# 8        337  3.87  3.78  2.49
# 9        338  4.00  4.05  2.39
# 10       339  4.25  4.28  2.73
# 11       340  3.93  3.90  2.46
# 12       342  3.88  3.84  2.33
# 13       344  4.35  4.37  2.71
# 14       345  3.79  3.75  2.27
# 15       345  4.38  4.42  2.68
# 16       348  4.31  4.34  2.68
# 17       351  4.23  4.29  2.70
# 18       351  4.23  4.26  2.71
# 19       351  4.21  4.27  2.66
# 20       351  4.26  4.30  2.71
# 21       352  3.85  3.92  2.48
# 22       353  3.94  3.96  2.41
# 23       353  4.39  4.43  2.62
# 24       353  4.44  4.47  2.59
# 25       354  3.97  4.01  2.41
# 26       355  3.97  3.94  2.47
# 27       357  4.28  4.30  2.67
# 28       357  3.96  3.97  2.40
# ...
